# %%
import numpy as np
import pandas as pd

# %%
url = 'https://voteview.com/static/data/out/members/HS119_members.csv'
ideology = pd.read_csv(url)
ideology.head(3).T

cols_to_keep = ['bioname', 'chamber', 'nominate_dim1', 'party_code']
crosswalk_cols = ['bioname', 'state_abbrev', 'district_code', 'icpsr', 'bioguide_id']

crosswalk = ideology[crosswalk_cols]
ideology = ideology[cols_to_keep]

# %%
ideology.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 545 entries, 0 to 544
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   bioname        545 non-null    object
#  1   chamber        545 non-null    object
#  2   nominate_dim1  545 non-null    float64
#  3   party_code     545 non-null    int64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 17.2+ KB

# %%
ideology['party_code'].value_counts()
# Out:
# party_code
# 200    279
# 100    264
# 328      2
# Name: count, dtype: int64

# %%
#help(pd.DataFrame)

# %%
replace_map = {200: 'Republican', 
               100: 'Democrat',
               328: "Independent"}
ideology['party'] = ideology['party_code'].replace(replace_map)
ideology['party'].value_counts()
# Out:
# party
# Republican     279
# Democrat       264
# Independent      2
# Name: count, dtype: int64

# %%
ideology = ideology.drop(['party_code'], axis = 1)

ideology
# Out:
#                        bioname chamber  nominate_dim1       party
# 0          ROGERS, Mike Dennis   House          0.378  Republican
# 1                SEWELL, Terri   House         -0.401    Democrat
# 2           PALMER, Gary James   House          0.674  Republican
# 3                 MOORE, Barry   House          0.645  Republican
# 4                 STRONG, Dale   House          0.606  Republican
# ..                         ...     ...            ...         ...
# 540  JUSTICE, James Conley, II  Senate          0.555  Republican
# 541             BALDWIN, Tammy  Senate         -0.487    Democrat
# 542               JOHNSON, Ron  Senate          0.641  Republican
# 543         LUMMIS, Cynthia M.  Senate          0.686  Republican
# 544          BARRASSO, John A.  Senate          0.540  Republican
#
# [545 rows x 4 columns]

# %%
ideology = ideology.rename({'nominate_dim1': 'left_right_ideology'}, axis = 1)
ideology
# Out:
#                        bioname chamber  left_right_ideology       party
# 0          ROGERS, Mike Dennis   House                0.378  Republican
# 1                SEWELL, Terri   House               -0.401    Democrat
# 2           PALMER, Gary James   House                0.674  Republican
# 3                 MOORE, Barry   House                0.645  Republican
# 4                 STRONG, Dale   House                0.606  Republican
# ..                         ...     ...                  ...         ...
# 540  JUSTICE, James Conley, II  Senate                0.555  Republican
# 541             BALDWIN, Tammy  Senate               -0.487    Democrat
# 542               JOHNSON, Ron  Senate                0.641  Republican
# 543         LUMMIS, Cynthia M.  Senate                0.686  Republican
# 544          BARRASSO, John A.  Senate                0.540  Republican
#
# [545 rows x 4 columns]

# %%
ideology.sort_values('left_right_ideology', ascending = False)
# Out:
#                                bioname chamber  left_right_ideology  \
# 398                      GILL, Brandon   House                0.981
# 296                      HARRIGAN, Pat   House                0.981
# 443  TUBERVILLE, Thomas Hawley (Tommy)  Senate                0.936
# 493              SCHMITT, Eric Stephen  Senate                0.918
# 129                    MCCORMICK, Rich   House                0.891
# ..                                 ...     ...                  ...
# 429                     RANDALL, Emily   House               -0.685
# 485                  WARREN, Elizabeth  Senate               -0.744
# 401                  TURNER, Sylvester   House               -0.746
# 381                     GARCIA, Sylvia   House               -0.781
# 66                     SIMON, Lateefah   House               -0.937
#
#           party
# 398  Republican
# 296  Republican
# 443  Republican
# 493  Republican
# 129  Republican
# ..          ...
# 429    Democrat
# 485    Democrat
# 401    Democrat
# 381    Democrat
# 66     Democrat
#
# [545 rows x 4 columns]

# %%
crosswalk
# Out:
#                        bioname state_abbrev  district_code  icpsr bioguide_id
# 0          ROGERS, Mike Dennis           AL              3  20301     R000575
# 1                SEWELL, Terri           AL              7  21102     S001185
# 2           PALMER, Gary James           AL              6  21500     P000609
# 3                 MOORE, Barry           AL              1  22140     M001212
# 4                 STRONG, Dale           AL              5  22366     S001220
# ..                         ...          ...            ...    ...         ...
# 540  JUSTICE, James Conley, II           WV              0  42504     J000312
# 541             BALDWIN, Tammy           WI              0  29940     B001230
# 542               JOHNSON, Ron           WI              0  41111     J000293
# 543         LUMMIS, Cynthia M.           WY              0  20953     L000571
# 544          BARRASSO, John A.           WY              0  40707     B001261
#
# [545 rows x 5 columns]

# %%
ideology_crosswalk = pd.merge(ideology, crosswalk, 
                              on = 'bioname')

ideology_crosswalk
# Out:
#                        bioname chamber  left_right_ideology       party  \
# 0          ROGERS, Mike Dennis   House                0.378  Republican
# 1                SEWELL, Terri   House               -0.401    Democrat
# 2           PALMER, Gary James   House                0.674  Republican
# 3                 MOORE, Barry   House                0.645  Republican
# 4                 STRONG, Dale   House                0.606  Republican
# ..                         ...     ...                  ...         ...
# 540  JUSTICE, James Conley, II  Senate                0.555  Republican
# 541             BALDWIN, Tammy  Senate               -0.487    Democrat
# 542               JOHNSON, Ron  Senate                0.641  Republican
# 543         LUMMIS, Cynthia M.  Senate                0.686  Republican
# 544          BARRASSO, John A.  Senate                0.540  Republican
#
#     state_abbrev  district_code  icpsr bioguide_id
# 0             AL              3  20301     R000575
# 1             AL              7  21102     S001185
# 2             AL              6  21500     P000609
# 3             AL              1  22140     M001212
# 4             AL              5  22366     S001220
# ..           ...            ...    ...         ...
# 540           WV              0  42504     J000312
# 541           WI              0  29940     B001230
# 542           WI              0  41111     J000293
# 543           WY              0  20953     L000571
# 544           WY              0  40707     B001261
#
# [545 rows x 8 columns]

# %%
ideology_crosswalk.query("state_abbrev == 'VA' & district_code == 5")

ideology_crosswalk.query("state_abbrev == 'VA'")
# Out:
#                           bioname chamber  left_right_ideology       party  \
# 410            WITTMAN, Robert J.   House                0.448  Republican
# 411   CONNOLLY, Gerald E. (Gerry)   House               -0.309    Democrat
# 412           GRIFFITH, H. Morgan   House                0.510  Republican
# 413    BEYER, Donald Sternoff Jr.   House               -0.395    Democrat
# 414               CLINE, Benjamin   House                0.716  Republican
# 415             KIGGANS, Jennifer   House                0.260  Republican
# 416           MCCLELLAN, Jennifer   House               -0.550    Democrat
# 417         MCGUIRE, John J., III   House                0.673  Republican
# 418            SUBRAMANYAM, Suhas   House               -0.301    Democrat
# 419         VINDMAN, Eugene Simon   House               -0.168    Democrat
# 420          WALKINSHAW, James R.   House               -0.503    Democrat
# 421              SCOTT, Robert C.   House               -0.450    Democrat
# 535                  WARNER, Mark  Senate               -0.208    Democrat
# 536  KAINE, Timothy Michael (Tim)  Senate               -0.243    Democrat
#
#     state_abbrev  district_code  icpsr bioguide_id
# 410           VA              1  20756     W000804
# 411           VA             11  20952     C001078
# 412           VA              9  21191     G000568
# 413           VA              8  21554     B001292
# 414           VA              6  21908     C001118
# 415           VA              2  22335     K000399
# 416           VA              4  22374     M001227
# 417           VA              5  22539     M001239
# 418           VA             10  22554     S001230
# 419           VA              7  22558     V000138
# 420           VA             11  22564     W000831
# 421           VA              3  39307     S000185
# 535           VA              0  40909     W000805
# 536           VA              0  41305     K000384

# %% [markdown]
# ## Vote similarity matrix

# %%
url = "https://voteview.com/static/data/out/votes/HS119_votes.csv"

votes = pd.read_csv(url)
votes.head(3).T

# %% [markdown]
# ## pd.merge(data1, data2, on, how, validate, indicator)
#
# Six arguments:
#
# * data1, data2" the two dataframes we want to join/merge
#
# * on: the column(s) whose values the dataframes share. If these columns don't have the same name, use left_on and right_on instead.
#
# * how: what to do with rows that do not have a match in the dataset
#
#     * inner : drop an unmatched row
#
#     * outer (full): keep all rows, if they don't match put missing values in teh unmatched part of the data
#
#     * left: keep everything from data1, drop unmatched rows from data2
#
#     * right: keep everything from data2, drop unmatched rows from data1
#
#     Note: It's a good idea to join outer, at first, to see if there are any problems with matching.
#
# * validate: "one_to_one", "many_to_one", "one_to_many", "many_to_many". Sets an expectation for how many rows in data2 one row in data1 will match to. If the expectation is not met, returns an error.
#
# * indicator: a new column that will tell you whether an ID (from th on feature) was found in both datasets, the left only, or right only

# %%
data1 = pd.DataFrame({'id': [1,1,1], 'x': [1,2,3]})

data2 = pd.DataFrame({'id': [1,1,1], 'y': [4,5,6]})

pd.merge(data1, data2, on = 'id')
# Out:
#    id  x  y
# 0   1  1  4
# 1   1  1  5
# 2   1  1  6
# 3   1  2  4
# 4   1  2  5
# 5   1  2  6
# 6   1  3  4
# 7   1  3  5
# 8   1  3  6

# %%
ideology_crosswalk = pd.merge(ideology, crosswalk,
         on = 'bioname',
         how = 'outer',
         validate = 'one_to_one',
         indicator = "matched")

# %%
ideology_crosswalk['matched'].value_counts()
# Out:
# matched
# both          545
# left_only       0
# right_only      0
# Name: count, dtype: int64

# %%
ideology_crosswalk = ideology_crosswalk.drop("matched", axis = 1)

# %%
votes = votes.drop(['congress', 'prob'], axis = 1)

votes
# Out:
#        chamber  rollnumber  icpsr  cast_code
# 0        House           1  14854          1
# 1        House           1  14863          1
# 2        House           1  14873          6
# 3        House           1  15029          6
# 4        House           1  15433          6
# ...        ...         ...    ...        ...
# 174605  Senate         530  42504          1
# 174606  Senate         530  42505          1
# 174607  Senate         530  42506          1
# 174608  Senate         530  49308          6
# 174609  Senate         530  49703          1
#
# [174610 rows x 4 columns]

# %%
vote_compare = pd.merge(votes, votes, 
                        on = ['chamber', 'rollnumber'],
                        how= 'outer',
                        indicator = 'matched',
                        validate = 'many_to_many')

# %%
vote_compare = vote_compare.drop(['matched'], axis = 1)
vote_compare = vote_compare.query("icpsr_x != icpsr_y")

# %%
vote_compare
# Out:
#          chamber  rollnumber  icpsr_x  cast_code_x  icpsr_y  cast_code_y
# 1          House           1    14854            1    14863            1
# 2          House           1    14854            1    14873            6
# 3          House           1    14854            1    15029            6
# 4          House           1    14854            1    15433            6
# 5          House           1    14854            1    15448            6
# ...          ...         ...      ...          ...      ...          ...
# 57936808  Senate         530    49703            1    42503            1
# 57936809  Senate         530    49703            1    42504            1
# 57936810  Senate         530    49703            1    42505            1
# 57936811  Senate         530    49703            1    42506            1
# 57936812  Senate         530    49703            1    49308            6
#
# [57762204 rows x 6 columns]

# %%
vote_compare['agree'] = vote_compare['cast_code_x'] == vote_compare['cast_code_x']

vote_compare
# Out:
#          chamber  rollnumber  icpsr_x  cast_code_x  icpsr_y  cast_code_y  \
# 1          House           1    14854            1    14863            1
# 2          House           1    14854            1    14873            6
# 3          House           1    14854            1    15029            6
# 4          House           1    14854            1    15433            6
# 5          House           1    14854            1    15448            6
# ...          ...         ...      ...          ...      ...          ...
# 57936808  Senate         530    49703            1    42503            1
# 57936809  Senate         530    49703            1    42504            1
# 57936810  Senate         530    49703            1    42505            1
# 57936811  Senate         530    49703            1    42506            1
# 57936812  Senate         530    49703            1    49308            6
#
#           agree
# 1          True
# 2          True
# 3          True
# 4          True
# 5          True
# ...         ...
# 57936808   True
# 57936809   True
# 57936810   True
# 57936811   True
# 57936812   True
#
# [57762204 rows x 7 columns]

# %%
vote_compare = vote_compare.groupby(['icpsr_x', 'icpsr_y']).agg({'agree': 'mean'}).reset_index()

# %%
vote_compare.head()
# Out:
#    icpsr_x  icpsr_y  agree
# 0    14226    14435    1.0
# 1    14226    14858    1.0
# 2    14226    14871    1.0
# 3    14226    14921    1.0
# 4    14226    15021    1.0

# %%
crosswalk
# Out:
#                        bioname state_abbrev  district_code  icpsr bioguide_id
# 0          ROGERS, Mike Dennis           AL              3  20301     R000575
# 1                SEWELL, Terri           AL              7  21102     S001185
# 2           PALMER, Gary James           AL              6  21500     P000609
# 3                 MOORE, Barry           AL              1  22140     M001212
# 4                 STRONG, Dale           AL              5  22366     S001220
# ..                         ...          ...            ...    ...         ...
# 540  JUSTICE, James Conley, II           WV              0  42504     J000312
# 541             BALDWIN, Tammy           WI              0  29940     B001230
# 542               JOHNSON, Ron           WI              0  41111     J000293
# 543         LUMMIS, Cynthia M.           WY              0  20953     L000571
# 544          BARRASSO, John A.           WY              0  40707     B001261
#
# [545 rows x 5 columns]

# %%
vote_compare_dup = vote_compare.copy(deep = True)

# %%
vote_compare = pd.merge(vote_compare, crosswalk,
         left_on = 'icpsr_x',
        right_on = 'icpsr',
        how = 'outer',
        indicator = "matched",
        validate = 'many_to_one')

# %%
vote_compare = vote_compare[['bioname', 'icpsr_y', 'agree']]

# %%
vote_compare = pd.merge(vote_compare, crosswalk,
         left_on = 'icpsr_y',
        right_on = 'icpsr',
        how = 'outer',
        indicator = "matched",
        validate = 'many_to_one')

# %%
vote_compare
# Out:
#                                   bioname_x  icpsr_y  agree  \
# 0                       MARKEY, Edward John    14226    1.0
# 1            SCHUMER, Charles Ellis (Chuck)    14226    1.0
# 2                         WYDEN, Ronald Lee    14226    1.0
# 3       McCONNELL, Addison Mitchell (Mitch)    14226    1.0
# 4                    DURBIN, Richard Joseph    14226    1.0
# ...                                     ...      ...    ...
# 206035                SCHAKOWSKY, Janice D.    91980    1.0
# 206036                    DelBENE, Suzan K.    91980    1.0
# 206037                       MASSIE, Thomas    91980    1.0
# 206038                  CLYBURN, James Enos    91980    1.0
# 206039                     SCOTT, Robert C.    91980    1.0
#
#                        bioname_y state_abbrev  district_code  icpsr  \
# 0       GRASSLEY, Charles Ernest           IA              0  14226
# 1       GRASSLEY, Charles Ernest           IA              0  14226
# 2       GRASSLEY, Charles Ernest           IA              0  14226
# 3       GRASSLEY, Charles Ernest           IA              0  14226
# 4       GRASSLEY, Charles Ernest           IA              0  14226
# ...                          ...          ...            ...    ...
# 206035       VAN DREW, Jefferson           NJ              2  91980
# 206036       VAN DREW, Jefferson           NJ              2  91980
# 206037       VAN DREW, Jefferson           NJ              2  91980
# 206038       VAN DREW, Jefferson           NJ              2  91980
# 206039       VAN DREW, Jefferson           NJ              2  91980
#
#        bioguide_id matched
# 0          G000386    both
# 1          G000386    both
# 2          G000386    both
# 3          G000386    both
# 4          G000386    both
# ...            ...     ...
# 206035     V000133    both
# 206036     V000133    both
# 206037     V000133    both
# 206038     V000133    both
# 206039     V000133    both
#
# [206040 rows x 9 columns]

# %%
vote_compare = vote_compare[['bioname_x', 'bioname_y', 'agree']]
vote_compare = vote_compare.rename({'bioname_x': 'bioname',
                                   'bioname_y': 'comparison_member'}, axis = 1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[229], line 1
# ----> 1 vote_compare = vote_compare[['bioname_x', 'bioname_y', 'agree']]
#       2 vote_compare = vote_compare.rename({'bioname_x': 'bioname',
#       3                                    'bioname_y': 'comparison_member'}, axis = 1)
#
# File /opt/anaconda3/envs/ds6001/lib/python3.13/site-packages/pandas/core/frame.py:4113, in DataFrame.__getitem__(self, key)
#    4111     if is_iterator(key):
#    4112         key = list(key)
# -> 4113     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4115 # take() does not accept boolean indexers
#    4116 if getattr(indexer, "dtype", None) == bool:
#
# File /opt/anaconda3/envs/ds6001/lib/python3.13/site-packages/pandas/core/indexes/base.py:6212, in Index._get_indexer_strict(self, key, axis_name)
#    6209 else:
#    6210     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6212 self._raise_if_missing(keyarr, indexer, axis_name)
#    6214 keyarr = self.take(indexer)
#    6215 if isinstance(key, Index):
#    6216     # GH 42790 - Preserve name from an Index
#
# File /opt/anaconda3/envs/ds6001/lib/python3.13/site-packages/pandas/core/indexes/base.py:6264, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6261     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6263 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 6264 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['bioname_x'] not in index"

# %%
vote_compare
# Out:
#                                   bioname_y                 bioname_y  agree
# 0                       MARKEY, Edward John  GRASSLEY, Charles Ernest    1.0
# 1            SCHUMER, Charles Ellis (Chuck)  GRASSLEY, Charles Ernest    1.0
# 2                         WYDEN, Ronald Lee  GRASSLEY, Charles Ernest    1.0
# 3       McCONNELL, Addison Mitchell (Mitch)  GRASSLEY, Charles Ernest    1.0
# 4                    DURBIN, Richard Joseph  GRASSLEY, Charles Ernest    1.0
# ...                                     ...                       ...    ...
# 206035                SCHAKOWSKY, Janice D.       VAN DREW, Jefferson    1.0
# 206036                    DelBENE, Suzan K.       VAN DREW, Jefferson    1.0
# 206037                       MASSIE, Thomas       VAN DREW, Jefferson    1.0
# 206038                  CLYBURN, James Enos       VAN DREW, Jefferson    1.0
# 206039                     SCOTT, Robert C.       VAN DREW, Jefferson    1.0
#
# [206040 rows x 3 columns]

# %%
vote_compare[vote_compare['bioname'].str.contains('MGUIRE')]/sort_values('agree', ascending = False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/anaconda3/envs/ds6001/lib/python3.13/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'bioname'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[225], line 1
# ----> 1 vote_compare[vote_compare['bioname'].str.contains('MGUIRE')]/sort_values('agree', ascending = False)
#
# File /opt/anaconda3/envs/ds6001/lib/python3.13/site-packages/pandas/core/frame.py:4107, in DataFrame.__getitem__(self, key)
#    4105 if self.columns.nlevels > 1:
#    4106     return self._getitem_multilevel(key)
# -> 4107 indexer = self.columns.get_loc(key)
#    4108 if is_integer(indexer):
#    4109     indexer = [indexer]
#
# File /opt/anaconda3/envs/ds6001/lib/python3.13/site-packages/pandas/core/indexes/base.py:3819, in Index.get_loc(self, key)
#    3814     if isinstance(casted_key, slice) or (
#    3815         isinstance(casted_key, abc.Iterable)
#    3816         and any(isinstance(x, slice) for x in casted_key)
#    3817     ):
#    3818         raise InvalidIndexError(key)
# -> 3819     raise KeyError(key) from err
#    3820 except TypeError:
#    3821     # If we have a listlike key, _check_indexing_error will raise
#    3822     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3823     #  the TypeError.
#    3824     self._check_indexing_error(key)
#
# KeyError: 'bioname'

# %%
vote_compare_dup[['icpsr_x', 'icpsr_y']] = vote_compare_dup[['icpsr_x', 'icpsr_y']].replace(crosswalk['icpsr'].values, crosswalk['bioname'].values,)
vote_compare_dup
# Out:
#                          icpsr_x                              icpsr_y  agree
# 0       GRASSLEY, Charles Ernest                  MARKEY, Edward John    1.0
# 1       GRASSLEY, Charles Ernest       SCHUMER, Charles Ellis (Chuck)    1.0
# 2       GRASSLEY, Charles Ernest                    WYDEN, Ronald Lee    1.0
# 3       GRASSLEY, Charles Ernest  McCONNELL, Addison Mitchell (Mitch)    1.0
# 4       GRASSLEY, Charles Ernest               DURBIN, Richard Joseph    1.0
# ...                          ...                                  ...    ...
# 206035       VAN DREW, Jefferson                SCHAKOWSKY, Janice D.    1.0
# 206036       VAN DREW, Jefferson                    DelBENE, Suzan K.    1.0
# 206037       VAN DREW, Jefferson                       MASSIE, Thomas    1.0
# 206038       VAN DREW, Jefferson                  CLYBURN, James Enos    1.0
# 206039       VAN DREW, Jefferson                     SCOTT, Robert C.    1.0
#
# [206040 rows x 3 columns]
