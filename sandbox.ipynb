# %%
from contrans import contrans

# %%
ct = contrans()

# %%
ct.get_crosswalk()

# %%
ct.get_member_info(chamber = 'House', state = 'CA', district = "20")
# Out:
#         bioname chamber  left_right_ideology state_abbrev  district_code  \
# 61  FONG, Vince   House                0.451           CA             20
#
#     icpsr bioguide_id       party
# 61  22378     F000480  Republican

# %%
import pandas as pd
ideology = pd.read_csv('data/ideology.csv')

# %%
memberinfo = ct.get_member_info(chamber = 'House', state = 'CA', district = "20")
ct.vote_similarity_to_member(memberinfo)
# Out:
#                   comparison_member     agree
# 156787                JOHNSON, Mike  0.947368
# 156711              AMODEI, Mark E.  0.939502
# 156700                WOMACK, Steve  0.932384
# 156776                BERGMAN, John  0.932384
# 156708           FLEISCHMANN, Chuck  0.932384
# ...                             ...       ...
# 156702            WILSON, Frederica  0.238434
# 156691  CONNOLLY, Gerald E. (Gerry)  0.227941
# 156845              SHERRILL, Mikie  0.174377
# 157050         WALKINSHAW, James R.  0.157895
# 156652            GRIJALVA, Raúl M.  0.000000
#
# [442 rows x 2 columns]

# %%
cm_header = pd.read_csv('data/cm_header_file.csv')
cm = pd.read_csv('data/cm.txt', sep='|', header = None, names=cm_header.columns)

# %%
ind_header = pd.read_csv('data/indiv_header_file.csv')
ind = pd.read_csv('data/itcont.txt', sep='|', header = None, names=ind_header.columns)
# Out:
# /var/folders/l2/ql1ypp8x1217sf5tb_mw1cmh0000gp/T/ipykernel_76866/4237425810.py:2: DtypeWarning: Columns (3,10,15,16,18,19) have mixed types. Specify dtype option on import or set low_memory=False.
#   ind = pd.read_csv('data/itcont.txt', sep='|', header = None, names=ind_header.columns)

# %%
contrib = pd.merge(ind, cm, how='outer', on='CMTE_ID', indicator=True, validate='many_to_one')

# %%
contrib.head(5)
# Out:
#      CMTE_ID AMNDT_IND RPT_TP TRANSACTION_PGI     IMAGE_NUM TRANSACTION_TP  \
# 0  C00000059         N     M2               P  2.025021e+17             15
# 1  C00000059         N     M2               P  2.025021e+17             15
# 2  C00000059         N     M4               P  2.025040e+17             15
# 3  C00000059         N     M4               P  2.025040e+17             15
# 4  C00000059         N     M4               P  2.025040e+17             15
#
#   ENTITY_TP                   NAME         CITY STATE  ... CMTE_ST CMTE_ZIP  \
# 0       IND       HALL, DAVID EARL  KANSAS CITY    MO  ...      MO    64108
# 1       IND  HALL, DONALD JOYCE JR  KANSAS CITY    MO  ...      MO    64108
# 2       IND       HALL, DAVID EARL  KANSAS CITY    MO  ...      MO    64108
# 3       IND          BAXTER, JENNI  KANSAS CITY    MO  ...      MO    64108
# 4       IND         PERRY, MICHAEL  KANSAS CITY    MO  ...      MO    64108
#
#   CMTE_DSGN  CMTE_TP  CMTE_PTY_AFFILIATION CMTE_FILING_FREQ ORG_TP  \
# 0         B        Q                   UNK                M      C
# 1         B        Q                   UNK                M      C
# 2         B        Q                   UNK                M      C
# 3         B        Q                   UNK                M      C
# 4         B        Q                   UNK                M      C
#
#        CONNECTED_ORG_NM CAND_ID _merge
# 0  HALLMARK CARDS, INC.     NaN   both
# 1  HALLMARK CARDS, INC.     NaN   both
# 2  HALLMARK CARDS, INC.     NaN   both
# 3  HALLMARK CARDS, INC.     NaN   both
# 4  HALLMARK CARDS, INC.     NaN   both
#
# [5 rows x 36 columns]

# %%
contrib.to_csv('data/contrib.csv', index = False)
